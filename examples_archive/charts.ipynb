# %%
#!pip install contextily
#!pip install osmnx
#!pip install pysal
#!pip install palettable

# %%
import helpers.scrapping
from helpers.scrapping import amenities, shops, composition_chart, compare_places, get_place_POI_tags
# Out:
# --- Import helpers ---
# /opt/mamba/lib/python3.10/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /home/onyxia/work/BATO-MOUCHE-Stat-App/helpers/scrapping.py:1: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# ...

# %%
composition_chart("Opéra Garnier", tags = {"shop": shops, "amenity" : amenities}, 
                  categories = ["restaurant", "culture and art", "education", "food_shops",
                                'supply_shops', 'fashion_beauty'])
# Out:
# /home/onyxia/work/BATO-MOUCHE-Stat-App/helpers/scrapping.py:151: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_pois["center"]=gdf_pois.centroid
# /home/onyxia/work/BATO-MOUCHE-Stat-App/helpers/scrapping.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['category'][i] = x
# /home/onyxia/work/BATO-MOUCHE-Stat-App/helpers/scrapping.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['category'][i] = x

# %%
places = ["Gare du Nord", "Porte de la Chapelle", "Opéra Garnier", "Sacré Coeur", "Place de la Bastille", 
          "Arc de triomphe", "Parc des buttes Chaumont"]

compare_places(places, tags = {"shop": shops, 'amenity' : amenities}, 
               categories = ["restaurant", "culture and art", "education", "food_shops", 'supply_shops', 
                             'fashion_beauty'])
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# /home/onyxia/work/BATO-MOUCHE-Stat-App/helpers/scrapping.py:151: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_pois["center"]=gdf_pois.centroid
# /home/onyxia/work/BATO-MOUCHE-Stat-App/helpers/scrapping.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['category'][i] = x
# /home/onyxia/work/BATO-MOUCHE-Stat-App/helpers/scrapping.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['category'][i] = x
# ...
